# %%
import os, sys
import numpy as np
import matplotlib.pyplot as mpl
import scipy as sp
import pandas as pd
from mayavi import mlab

# %%
sys.path.append("./bin/")
import ZernikeFunc as ZF
import SurfaceFunc as SF
import MyUtils as MU  # my personal collection of functions

# %% [markdown]
# ## Parametri iniziali

# %%
# Parameters definition
Npixel = 25    # the plane edge in pixels
Rs = 6         # the radius of the sphere that includes the patch
Dpp = 0.5      # the distance between points of the same patch (needed to remove islands)
center = 5000   # point of the surface used as center of the patch (default value)
ZOrder = 20    # the Zernike expansion order
threshold = 5  # value to enstablish variance is high (in Angstrom units)
Daa = 3        # threshold to find points in contact between two proteins (in Angstrom units)

# %%
### To load a new surface:
surf_name_a = "./data/4bs2_RRM2.dms"
surf_a_ = pd.read_csv(surf_name_a)  
l_a = len(surf_a_["x"])
print("Npoints", l_a)
surf_a = np.zeros((l_a, 6))
surf_a[:,:] = surf_a_[["x", "y", "z", "Nx", "Ny", "Nz"]]

### To inizialize the Surface class:
surf_a_obj = SF.Surface(surf_a[:,:], patch_num = 0, r0 = Rs, theta_max = 45)
# Out:
# Npoints 23878

# %% [markdown]
# ## Ricostruzione di Zernike (Parte Extra)

# %%
# %%time
center = 5000
plane, plane_var, perc = MU.PercHigherVariance_Weigths(Npixel, surf_a_obj, center, Dpp, threshold)
plane_proc, plane_recon, plane_coeff = MU.PlaneRebuild(surf_a_obj, plane, ZOrder)
# Out:
# C:\Users\karlmarx\Documents\ALESSANDRO\Laboratorio_2\Zernike2D\Zernike_Lab_Summary\./bin\ZernikeFunc.py:315: RuntimeWarning: divide by zero encountered in double_scalars
#   t = np.arctan(np.abs(y/x))
# C:\Users\karlmarx\Documents\ALESSANDRO\Laboratorio_2\Zernike2D\Zernike_Lab_Summary\./bin\ZernikeFunc.py:315: RuntimeWarning: invalid value encountered in double_scalars
#   t = np.arctan(np.abs(y/x))
# Wall time: 47 s

# %%
MU.PlotPlaneRebuild(center, Dpp, Rs, ZOrder, plane, plane_proc, plane_recon.real, [], "")

# To save figure
#MU.PlotPlaneRebuild(center, Dpp, Rs, ZOrder, plane, plane_proc, plane_recon.real, [], "Point{}_Order{}_Weigths".format(center, ZOrder))

# %%
# %%time
center = 5000
plane, plane_var, perc = MU.PercHigherVariance_Projections(Npixel, surf_a_obj, center, Dpp, threshold)
plane_proc, plane_recon, plane_coeff = MU.PlaneRebuild(surf_a_obj, plane, ZOrder)
# Out:
# Wall time: 45.5 s

# %%
MU.PlotPlaneRebuild(center, Dpp, Rs, ZOrder, plane, plane_proc, plane_recon.real, [], "")

# To save figure
#MU.PlotPlaneRebuild(center, Dpp, Rs, ZOrder, plane, plane_proc, plane_recon.real, [], "Point{}_Order{}_Projection".format(center, ZOrder))

# %%
# %%time
center = 19841
plane, plane_var, perc = MU.PercHigherVariance_Weigths(Npixel, surf_a_obj, center, Dpp, threshold)
plane_proc, plane_recon, plane_coeff = MU.PlaneRebuild(surf_a_obj, plane, ZOrder)
# Out:
# Wall time: 45.7 s

# %%
MU.PlotPlaneRebuild(center, Dpp, Rs, ZOrder, plane, plane_proc, plane_recon.real, [], "")

# To save figure
#MU.PlotPlaneRebuild(center, Dpp, Rs, ZOrder, plane, plane_proc, plane_recon.real, [], "Point{}_Order{}_Weigths".format(center, ZOrder))

# %%
# %%time
center = 19841
plane, plane_var, perc = MU.PercHigherVariance_Projections(Npixel, surf_a_obj, center, Dpp, threshold)
plane_proc, plane_recon, plane_coeff = MU.PlaneRebuild(surf_a_obj, plane, ZOrder)
# Out:
# Wall time: 46.2 s

# %%
MU.PlotPlaneRebuild(center, Dpp, Rs, ZOrder, plane, plane_proc, plane_recon.real, [], "")

# To save figure
#MU.PlotPlaneRebuild(center, Dpp, Rs, ZOrder, plane, plane_proc, plane_recon.real, [], "Point{}_Order{}_Projection".format(center, ZOrder))

# %%
# %%time
center = 8227
plane, plane_var, perc = MU.PercHigherVariance_Weigths(Npixel, surf_a_obj, center, Dpp, threshold)
plane_proc, plane_recon, plane_coeff = MU.PlaneRebuild(surf_a_obj, plane, ZOrder)
# Out:
# Wall time: 46.1 s

# %%
MU.PlotPlaneRebuild(center, Dpp, Rs, ZOrder, plane, plane_proc, plane_recon.real, [], "")

# To save figure
#MU.PlotPlaneRebuild(center, Dpp, Rs, ZOrder, plane, plane_proc, plane_recon.real, [], "Point{}_Order{}_Weigths".format(center, ZOrder))

# %%
# %%time
center = 8227
plane, plane_var, perc = MU.PercHigherVariance_Projections(Npixel, surf_a_obj, center, Dpp, threshold)
plane_proc, plane_recon, plane_coeff = MU.PlaneRebuild(surf_a_obj, plane, ZOrder)
# Out:
# Wall time: 44.5 s

# %%
MU.PlotPlaneRebuild(center, Dpp, Rs, ZOrder, plane, plane_proc, plane_recon.real, [], "")

# To save figure
#MU.PlotPlaneRebuild(center, Dpp, Rs, ZOrder, plane, plane_proc, plane_recon.real, [], "Point{}_Order{}_Projection".format(center, ZOrder))
